# %%
from relaxations_modular import relax_fb_analytical
from parameters import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import CubicSpline
from scipy.optimize import minimize

# %%
params = [-4.51406644e-05, -2.11366484e-05,  2.65883301e-05]

# %%
m, sol = relax_fb_analytical(params)
# Out:
# finalizing integrator...
# integrating...
# Integration progress:   0%|          | 0/100000 [00:00<?, ?it/s]
# Generating, compiling, and loading C code.
# Integration progress: 100%|██████████| 100000/100000 [00:08<00:00, 12270.81it/s]

# %%
plt.plot([s[6] for s in sol])

# %%
plt.plot(sol[:,6])
